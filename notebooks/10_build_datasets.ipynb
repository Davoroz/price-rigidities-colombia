# %% [markdown]
# # Preprocess code
# ## Universidad ICESI
# ### David Mauricio Orozco Rios
# ### author: Davoroz06 - IG

# %%
import papermill as pm

for notebook in ["11_clean_store_A1.ipynb", "12_clean_store_A2.ipynb", "13_clean_store_C.ipynb",
                 "14_clean_store_B.ipynb", "15_join_retailers.ipynb"]:
    print("Running", notebook)
    pm.execute_notebook(notebook, None)
