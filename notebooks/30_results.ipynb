# %% [markdown]
# # Results code
# ## Universidad ICESI
# ### David Mauricio Orozco Rios
# ### author: Davoroz06 - IG

# %%
import papermill as pm

# %%
regular_window = 14
reference_window = 30
case = "Comparison"

# %%
pm.execute_notebook(
    "31_tables.ipynb",  # Input notebook
    None,  # For No Output notebook
    parameters={"case": case, "regular_window": regular_window, "reference_window": reference_window}  # Parameters to pass
)

# %%
pm.execute_notebook(
    "32_figures.ipynb",  # Input notebook
    None,  # For No Output notebook
    parameters={"case":case, "regular_window": regular_window, "reference_window": reference_window}  # Parameters to pass
)
