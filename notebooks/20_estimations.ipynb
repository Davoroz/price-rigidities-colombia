# %% [markdown]
# # Estimation code
# ## Universidad ICESI
# ### David Mauricio Orozco Rios
# ### author: Davoroz06 - IG

# %%
import papermill as pm

# %%
run_filter = False
case = "Comparison"
regular_window = 14
reference_window = 30

# %%
if run_filter:
    pm.execute_notebook(
        "21_filter_data.ipynb",  # Input notebook
        None,  # For No Output notebook
        parameters={"case": case, "regular_window": regular_window, "reference_window": reference_window}  # Parameters to pass
    )

# %%
pm.execute_notebook(
    "22_regular_price_nakamura.ipynb",  # Input notebook
    None,  # For No Output notebook
    parameters={"case": case, "regular_window": regular_window, "reference_window": reference_window}  # Parameters to pass
)

# %%
pm.execute_notebook(
    "23_reference_price_eichenbaum.ipynb",  # Input notebook
    None,  # For No Output notebook
    parameters={"case": case, "regular_window": regular_window, "reference_window": reference_window} # Parameters to pass
)

# %%
print(f"Processing with {regular_window} window for regular price")
pm.execute_notebook(
    "24_price_setting.ipynb",  # Input notebook
    None,  # For No Output notebook
    parameters={"case": case, "regular_window": regular_window, "reference_window": reference_window} # Parameters to pass
)
